# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('titanic')

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.histplot(data=df,x=df['age'],bins=40,hue='survived',multiple='stack')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.catplot(data=df,x='pclass',y='age',kind='violin',hue='sex',split=True)

# %%
sns.catplot(
    data=df,
    x='class',
    y='age',
    kind='strip',   # Har point ek dot
    hue='survived',
   # dodge=True,     # Categories ko thoda side-shift karo taaki overlap na ho
    alpha=0.6       # Transparency (0=fully transparent, 1=opaque)
)

# %%
sns.catplot(
    data=df,
    x='class',
    y='age',
    kind='swarm',   # Har point ek dot
    hue='sex',
    # dodge=True,     # Categories ko thoda side-shift karo taaki overlap na ho
    size=2# Transparency (0=fully transparent, 1=opaque)
)

# %%
g=sns.FacetGrid(data=newage,
                col='class',
               height=4)
g.map(sns.histplot,'age',bins=3)
plt.show()

# %%
print("Shape:", df.shape)
print("pclass unique:", df['pclass'].unique())
print("age nulls:", newage['age'].isnull().sum())
print("Seaborn version:", sns.__version__)
# Out:
# Shape: (891, 15)
# pclass unique: [3 1 2]
# age nulls: 0
# Seaborn version: 0.13.2

# %%
newage=df.dropna(subset=['age'])

# %%
df_clean = df.dropna(subset=['age'])   # Age ke NaN wali rows delete

# Ab FacetGrid banayo
g = sns.FacetGrid(data=df_clean, col='pclass', height=4, aspect=1.2)
g.map(sns.histplot, 'age', kde=True, bins=15, color='coral')
g.set_axis_labels('Age', 'Count')
g.set_titles('Class {col_name}')
plt.show()

# %%
df = df.dropna(subset=['age'])  # NaN fix

# ====== STYLE 1: darkgrid (default) ======
sns.set_theme(style='darkgrid')
sns.histplot(data=df, x='age', hue='pclass', kde=True)
plt.title("Style: darkgrid")
plt.show()
