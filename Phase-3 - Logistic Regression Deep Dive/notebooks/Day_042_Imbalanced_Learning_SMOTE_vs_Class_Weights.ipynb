# %% [markdown]
# # 📅 Day 042: Imbalanced Learning: SMOTE vs Class Weights
#
# **Description:** Oversampling vs cost-sensitive learning, under/over-sampling tradeoffs.
#
# **Theory & Study:** Study Imbalanced Learning: SMOTE vs Class Weights deeply enough to explain the intuition, identify when to use it, and connect it to the previous roadmap topics.
#
# ## 📖 Concept Notes
# > Write your 3-5 key takeaways/notes here.
#
# ## 💻 Code & Practice
# Implement your exercises and tests in this section.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set style
sns.set_theme(style="darkgrid")

# %% [markdown]
# ## 🛠️ Build / Submit Task
# **Task Description:** Phase-3/Day 042 - Imbalance Handling.ipynb.
#
# Write your main implementation cells below.

# %%
# Your code here

# %% [markdown]
# ## ✅ Verification
# **Task Description:** Open/run the deliverable, check outputs, and make sure it is ready for revision or portfolio use.

# %%
# Your verification code here
