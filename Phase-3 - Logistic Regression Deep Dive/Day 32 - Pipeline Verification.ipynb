# %% [markdown]
# # Day 32: Pipeline Verification with Pytest
# ### Target: Set up and run automated test suites on your trained model pipeline using pytest.
#
# **Tasks to implement:**
# 1. Run the test suite via terminal command `pytest test_pipeline.py` or programmatically using `pytest.main()` inside this notebook.

# %%
# Write your test runner execution code below
