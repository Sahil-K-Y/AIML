# %% [markdown]
# # Day 33: Sigmoid, Odds, and Log-Odds Mathematical Simulation
# ### Target: Build intuition about the logistic link function.
#
# **Tasks to implement:**
# 1. Implement the mathematical Sigmoid function: $S(z) = \frac{1}{1 + e^{-z}}$.
# 2. Generate an array of $z$ (log-odds) values from -7 to 7.
# 3. Compute corresponding probability values and plot the curve using `matplotlib`.

# %%
# Write your Sigmoid and odds simulation code below
