# %% [markdown]
# # Day 28: Titanic Pipeline Verification (With pytest Unit Tests)
# ### Target: Validate the model preprocessing steps, shape outputs, and probability boundaries using pytest.
#
# Writing unit tests for machine learning code is essential to prevent silent bugs. For example, a pipeline might silently input incorrect values or crash when receiving unexpected NaNs. In this notebook, we run our unit tests defined in `test_pipeline.py` directly from the notebook.

# %% [markdown]
# ## 1. Inspect the pytest Suite
# Let's print the contents of `test_pipeline.py` to see the structure of our assertions.

# %%
with open('test_pipeline.py', 'r', encoding='utf-8') as f:
    print(f.read())

# %% [markdown]
# ## 2. Run the tests using pytest
# We trigger `pytest` inside our environment to verify the tests pass successfully.

# %%
# !pytest test_pipeline.py -v

# %% [markdown]
# ## 3. Log Output Review
# Let's inspect the last 15 lines of `pipeline.log` to confirm our production logger correctly instrumented the pipeline execution.

# %%
if os.path.exists('pipeline.log'):
    with open('pipeline.log', 'r', encoding='utf-8') as f:
        lines = f.readlines()
        for line in lines[-15:]:
            print(line.strip())
else:
    print('Log file pipeline.log not found.')
