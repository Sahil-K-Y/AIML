# %% [markdown]
# # Day 31: Titanic Pipeline Architecture with Logging
# ### Target: Build a robust, production-grade scikit-learn pipeline with customized runtime logging.
#
# **Tasks to implement:**
# 1. Initialize logging using `logging.basicConfig` to stream logs and save them to `pipeline.log`.
# 2. Load the `train.csv` file using pandas.
# 3. Separate features (`['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']`) and target (`Survived`).
# 4. Perform train/validation split (test_size=0.2).
# 5. Build numeric preprocessing pipeline (`SimpleImputer` + `StandardScaler`).
# 6. Build categorical preprocessing pipeline (`SimpleImputer` + `OneHotEncoder`).
# 7. Combine preprocessors with `ColumnTransformer` and feed into a `LogisticRegression` classifier within a unified `Pipeline`.
# 8. Train/fit the model and print the validation accuracy score.
# 9. Save the fitted pipeline model using `joblib.dump` to `titanic_pipeline.joblib`.

# %%
# Write your Day 31 model pipeline code below
