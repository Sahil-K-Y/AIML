# %%
from sklearn.metrics import mean_squared_error

y_actual = [30, 50, 65, 80, 110]
y_predicted = [29, 48, 67, 86, 105]

mse = mean_squared_error(y_actual, y_predicted)
print("MSE:", mse)   # 14.0 aayega
# Out:
# MSE: 14.0
